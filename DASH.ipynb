# %%
import dash
import dash_table
import dash_core_components as dcc
import dash_html_components as html
import plotly.graph_objs as go
import numpy as np
import pandas as pd

# %%
app=dash.Dash(__name__)

# %%
df = pd.read_csv('data sirup update.csv')
df=df.drop(columns=['Unnamed: 0'])
tabel_jumlah_tender_tahun2020=df[['nama','waktu']].loc[df['waktu'] != '2021-01-01'].loc[df['waktu'] != '2023-10-01'].loc[df['waktu'] != '2023-04-01'].groupby(['waktu'],as_index=False).count()
tabel_jumlah_tender_tahun2020.rename(columns = {'nama':'Jumlah Tender'}, inplace = True)
tabel_jumlah_tender_tahun2020
df.head()
# Out:
#    idBulan              metode                             nama  \
# 0       10        E-Purchasing  Pengadaan Lemari Besi Fireproof
# 1       10        E-Purchasing  Pengadaan Lemari Besi Fireproof
# 2        4  Pengadaan Langsung          Pengadaan Kursi Pejabat
# 3        1  Pengadaan Langsung        Belanja Bahan Pakai Habis
# 4       12  Pengadaan Langsung   Pengadaan Frame Acrilik Poster
#
#                                    instansi lokasi   jenis       waktu  \
# 0                      Kementerian Keuangan      -  Barang  2023-10-01
# 1                      Kementerian Keuangan      -  Barang  2023-10-01
# 2  Pemerintah Daerah Kabupaten Buton Tengah      -  Barang  2023-04-01
# 3              Pemerintah Daerah Kota Depok      -  Barang  2021-01-01
# 4                     Kementerian Kesehatan      -  Barang  2020-12-01
#
#    idMetode        id       pagu  idJenisPengadaan  \
# 0         9  22319671   23000000                 1
# 1         9  22319671   23000000                 1
# 2         8  20854093    5000000                 1
# 3         8  20376353   10513000                 1
# 4         8  22867952  120000000                 1
#
#                                          satuanKerja
# 0  DIREKTORAT JENDERAL PENGELOLAAN PEMBIAYAAN DAN...
# 1  DIREKTORAT JENDERAL PENGELOLAAN PEMBIAYAAN DAN...
# 2  DINAS KOMUNIKASI INFORMATIKA STATISTIK DAN PER...
# 3     DINAS KETAHANAN PANGAN PERTANIAN DAN PERIKANAN
# 4  SEKRETARIAT DIREKTORAT JENDERAL PELAYANAN KESE...

# %%
df.loc[df['waktu'] == '2020-01-01']
# Out:
#       idBulan        metode  \
# 585         1        Tender
# 586         1        Tender
# 587         1       Seleksi
# 588         1        Tender
# 589         1       Seleksi
# ...       ...           ...
# 1430        1  Dikecualikan
# 1431        1        Tender
# 1432        1       Seleksi
# 1433        1  Dikecualikan
# 1434        1  Dikecualikan
#
#                                                    nama  \
# 585   PRESERVASI JALAN LINGKAR PULAU SEBATIK
# 586   Pembangunan Gudang Terbuka untuk Kendaraan Tan...
# 587   Supervisi Pembangunan IPA Kap. 20 L/detik SPAM...
# 588   Pembangunan Jaringan Perpipaan Spam IKK Bajuin...
# 589        Supervisi Pembangunan IPLT Kab. Flores Timur
# ...                                                 ...
# 1430  Belanja Jasa Akomodasi Pelatihan Imam Masjid A...
# 1431     Belanja Modal Pengadaan Alat Pemadam Kebakaran
# 1432                           Review pola PSDA Tahap 1
# 1433      Belanja Jasa Akomodasi Imam Masjid Angkatan V
# 1434     Belanja Jasa Akomodasi Imam Masjid Angkatan IV
#
#                                              instansi  \
# 585   Kementerian Pekerjaan Umum dan Perumahan Rakyat
# 586   Kementerian Pekerjaan Umum dan Perumahan Rakyat
# 587   Kementerian Pekerjaan Umum dan Perumahan Rakyat
# 588   Kementerian Pekerjaan Umum dan Perumahan Rakyat
# 589   Kementerian Pekerjaan Umum dan Perumahan Rakyat
# ...                                               ...
# 1430        Pemerintah Daerah Provinsi Sumatera Barat
# 1431      Pemerintah Daerah Provinsi Kalimantan Timur
# 1432  Kementerian Pekerjaan Umum dan Perumahan Rakyat
# 1433        Pemerintah Daerah Provinsi Sumatera Barat
# 1434        Pemerintah Daerah Provinsi Sumatera Barat
#
#                                          lokasi                   jenis  \
# 585          Kalimantan Utara-Bulungan (Kab.),   Pekerjaan Konstruksi,
# 586    Kalimantan Tengah-Palangka Raya (Kota),   Pekerjaan Konstruksi,
# 587      Sumatera Utara-Tapanuli Utara (Kab.),       Jasa Konsultansi,
# 588      Kalimantan Selatan-Tanah Laut (Kab.),   Pekerjaan Konstruksi,
# 589   Nusa Tenggara Timur-Flores Timur (Kab.),       Jasa Konsultansi,
# ...                                         ...                     ...
# 1430                                          -            Jasa Lainnya
# 1431            Kalimantan Timur-Paser (Kab.),                 Barang,
# 1432                Jawa Barat-Bandung (Kota),       Jasa Konsultansi,
# 1433                                          -            Jasa Lainnya
# 1434                                          -            Jasa Lainnya
#
#            waktu  idMetode        id         pagu  idJenisPengadaan  \
# 585   2020-01-01        13  22745880  50000000000                 0
# 586   2020-01-01        13  22741970    495000000                 0
# 587   2020-01-01        15  22742050   1007500000                 0
# 588   2020-01-01        13  22742632    300000000                 0
# 589   2020-01-01        15  22742944    500000000                 0
# ...          ...       ...       ...          ...               ...
# 1430  2020-01-01        16  22421624     56000000                 4
# 1431  2020-01-01        13  22139846    938000000                 0
# 1432  2020-01-01        15  22744714    494680000                 0
# 1433  2020-01-01        16  22424242     56000000                 4
# 1434  2020-01-01        16  22424197     56000000                 4
#
#                                             satuanKerja
# 585   PELAKSANAAN JALAN NASIONAL WILAYAH I PROVINSI ...
# 586   BALAI PRASARANA PERMUKIMAN WILAYAH KALIMANTAN ...
# 587   PELAKSANAAN PRASARANA PERMUKIMAN WILAYAH I PRO...
# 588   PELAKSANAAN PRASARANA PERMUKIMAN PROVINSI KALI...
# 589   PELAKSANAAN PRASARANA PERMUKIMAN WILAYAH II PR...
# ...                                                 ...
# 1430  BIRO BINA MENTAL DAN KESEJAHTERAAN RAKYAT SETD...
# 1431                                    Dinas Kehutanan
# 1432                 BALAI BESAR WILAYAH SUNGAI CITARUM
# 1433  BIRO BINA MENTAL DAN KESEJAHTERAAN RAKYAT SETD...
# 1434  BIRO BINA MENTAL DAN KESEJAHTERAAN RAKYAT SETD...
#
# [850 rows x 12 columns]

# %%
app.layout = html.Div([
    
    dcc.Graph(id='chart',
             figure={'data':[go.Scatter(x=tabel_jumlah_tender_tahun2020['waktu'],
                                       y=tabel_jumlah_tender_tahun2020['Jumlah Tender'])
                            ],
                    'layout':go.Layout(title='CHART TENDER 2020',
                                      xaxis={'title':'Bulan Tahun'},
                                      yaxis={'title':'Jumlah Tender'})}),
    dash_table.DataTable(id='table',
                         columns=[{"name": i, "id": i} for i in df.columns],
                         data=df.to_dict('records'),n_fixed_rows=1,
)
])

# %%
if __name__=='__main__':
    app.run_server(port=4050)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:4050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [28/Dec/2019 23:28:41] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Dec/2019 23:28:41] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Dec/2019 23:28:41] "GET /_dash-layout HTTP/1.1" 200 -
